# %% [markdown]
# # Market Basket Analysis on Telecom Product Data

# %% [markdown]
# ## Research Question

# %% [markdown]
# #### _"What top related products/product groupings are items of interest for customers that we can incentivize by discounting to entice more customer purchases and reduce customer churn?"_

# %% [markdown]
# ### Show Python Version

# %%
import sys
sys.version_info
# Out:
# sys.version_info(major=3, minor=8, micro=8, releaselevel='final', serial=0)

# %% [markdown]
# ### Import necessary libraries/packages

# %%
from mlxtend.preprocessing import TransactionEncoder
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori, association_rules
from numpy import random
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Set random seed for reproducable results

# %%
random.seed(1234)

# %% [markdown]
# ### Read csv file into a pandas dataframe, drop any rows with all NaN values, and create an array from the DF

# %%
url = "C:/Users/tedda/Desktop/Data Science Portfolio/Machine Learning/Unsupervised Learning/Association/Market Basket Analysis on Telecom Product Data/Raw Datasets/teleco_market_basket.csv"
teleco_mb = pd.read_csv(url)
teleco_mb = teleco_mb.dropna(axis = 0, how ='all')
transactions = np.array(teleco_mb)

# %% [markdown]
# ### Example of one transaction in the dataset (pre-encoding)

# %%
transactions[0]
# Out:
# array(['Logitech M510 Wireless mouse', 'HP 63 Ink', 'HP 65 ink',
#        'nonda USB C to USB Adapter', '10ft iPHone Charger Cable',
#        'HP 902XL ink', 'Creative Pebble 2.0 Speakers',
#        'Cleaning Gel Universal Dust Cleaner',
#        'Micro Center 32GB Memory card',
#        'YUNSONG 3pack 6ft Nylon Lightning Cable',
#        'TopMate C5 Laptop Cooler pad', 'Apple USB-C Charger cable',
#        'HyperX Cloud Stinger Headset', 'TONOR USB Gaming Microphone',
#        'Dust-Off Compressed Gas 2 pack', '3A USB Type C Cable 3 pack 6FT',
#        'HOVAMP iPhone charger', 'SanDisk Ultra 128GB card',
#        'FEEL2NICE 5 pack 10ft Lighning cable',
#        'FEIYOLD Blue light Blocking Glasses'], dtype=object)

# %% [markdown]
# ### Onehot encode the array by using TransactionEncoder()

# %%
encoder = TransactionEncoder()
onehot = encoder.fit_transform(transactions.astype(str))
onehot = pd.DataFrame(onehot, columns = encoder.columns_)
onehot.drop('nan', axis = 1, inplace = True)
print(onehot.shape)
onehot.head()
# Out:
# (7501, 119)
#    10ft iPHone Charger Cable  10ft iPHone Charger Cable 2 Pack  \
# 0                       True                             False
# 1                      False                             False
# 2                      False                             False
# 3                      False                             False
# 4                      False                             False
#
#    3 pack Nylon Braided Lightning Cable  3A USB Type C Cable 3 pack 6FT  \
# 0                                 False                            True
# 1                                 False                           False
# 2                                 False                           False
# 3                                 False                           False
# 4                                 False                           False
#
#    5pack Nylon Braided USB C cables  ARRIS SURFboard SB8200 Cable Modem  \
# 0                             False                               False
# 1                             False                               False
# 2                             False                               False
# 3                             False                               False
# 4                             False                               False
#
#    Anker 2-in-1 USB Card Reader  Anker 4-port USB hub  \
# 0                         False                 False
# 1                         False                 False
# 2                         False                 False
# 3                         False                 False
# 4                         False                 False
#
#    Anker USB C to HDMI Adapter  Apple Lightning to Digital AV Adapter  ...  \
# 0                        False                                  False  ...
# 1                        False                                   True  ...
# 2                        False                                  False  ...
# 3                        False                                  False  ...
# 4                        False                                  False  ...
#
#    hP 65 Tri-color ink  iFixit Pro Tech Toolkit  iPhone 11 case  \
# 0                False                    False           False
# 1                False                    False           False
# 2                False                    False           False
# 3                False                    False           False
# 4                False                    False           False
#
#    iPhone 12 Charger cable  iPhone 12 Pro case  iPhone 12 case  \
# 0                    False               False           False
# 1                    False               False           False
# 2                    False               False           False
# 3                    False               False           False
# 4                    False               False           False
#
#    iPhone Charger Cable Anker 6ft  iPhone SE case  nonda USB C to USB Adapter  \
# 0                           False           False                        True
# 1                           False           False                       False
# 2                           False           False                       False
# 3                           False           False                       False
# 4                           False           False                       False
#
#    seenda Wireless mouse
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False
#
# [5 rows x 119 columns]

# %% [markdown]
# ### Export the encoded dataset used for Market Basket Analysis

# %%
onehot.to_csv("C:/Users/tedda/Desktop/Data Science Portfolio/Machine Learning/Unsupervised Learning/Association/Market Basket Analysis on Telecom Product Data/Cleansed Datasets/encoded_dataset.csv", header = True)

# %% [markdown]
# ### Generate the frequent itemsets by using the Apriori Algorithm

# %%
frequent_itemsets = apriori(onehot, min_support = 0.01,
                            max_len = 4, use_colnames = True)

# %% [markdown]
# ### Generate the Association Rules of the frequent itemsets found by the Apriori Algorithm with no threshold

# %%
rules = association_rules(frequent_itemsets,
                         metric = 'support',
                         min_threshold = 0.0)
print(rules.shape)
rules
# Out:
# (432, 9)
#                                            antecedents  \
# 0                     (Dust-Off Compressed Gas 2 pack)
# 1                   (10ft iPHone Charger Cable 2 Pack)
# 2                   (10ft iPHone Charger Cable 2 Pack)
# 3                                          (HP 61 ink)
# 4                   (10ft iPHone Charger Cable 2 Pack)
# ..                                                 ...
# 427         (HP 61 ink, Screen Mom Screen Cleaner kit)
# 428  (VIVO Dual LCD Monitor Desk mount, Screen Mom ...
# 429                                        (HP 61 ink)
# 430                 (VIVO Dual LCD Monitor Desk mount)
# 431                    (Screen Mom Screen Cleaner kit)
#
#                                            consequents  antecedent support  \
# 0                   (10ft iPHone Charger Cable 2 Pack)            0.238368
# 1                     (Dust-Off Compressed Gas 2 pack)            0.050527
# 2                                          (HP 61 ink)            0.050527
# 3                   (10ft iPHone Charger Cable 2 Pack)            0.163845
# 4                      (Screen Mom Screen Cleaner kit)            0.050527
# ..                                                 ...                 ...
# 427                 (VIVO Dual LCD Monitor Desk mount)            0.032129
# 428                                        (HP 61 ink)            0.035462
# 429  (VIVO Dual LCD Monitor Desk mount, Screen Mom ...            0.163845
# 430         (HP 61 ink, Screen Mom Screen Cleaner kit)            0.174110
# 431      (HP 61 ink, VIVO Dual LCD Monitor Desk mount)            0.129583
#
#      consequent support   support  confidence      lift  leverage  conviction
# 0              0.050527  0.023064    0.096756  1.914955  0.011020    1.051182
# 1              0.238368  0.023064    0.456464  1.914955  0.011020    1.401255
# 2              0.163845  0.010132    0.200528  1.223888  0.001853    1.045884
# 3              0.050527  0.010132    0.061839  1.223888  0.001853    1.012058
# 4              0.129583  0.015198    0.300792  2.321232  0.008651    1.244861
# ..                  ...       ...         ...       ...       ...         ...
# 427            0.174110  0.010932    0.340249  1.954217  0.005338    1.251821
# 428            0.163845  0.010932    0.308271  1.881480  0.005122    1.208790
# 429            0.035462  0.010932    0.066721  1.881480  0.005122    1.033494
# 430            0.032129  0.010932    0.062787  1.954217  0.005338    1.032712
# 431            0.039195  0.010932    0.084362  2.152382  0.005853    1.049329
#
# [432 rows x 9 columns]

# %% [markdown]
# ### Provide values for Support, Lift, and Confidence of the association rules table.

# %%
rules[['antecedents','consequents','support','confidence','lift']]
# Out:
#                                            antecedents  \
# 0                     (Dust-Off Compressed Gas 2 pack)
# 1                   (10ft iPHone Charger Cable 2 Pack)
# 2                   (10ft iPHone Charger Cable 2 Pack)
# 3                                          (HP 61 ink)
# 4                   (10ft iPHone Charger Cable 2 Pack)
# ..                                                 ...
# 427         (HP 61 ink, Screen Mom Screen Cleaner kit)
# 428  (VIVO Dual LCD Monitor Desk mount, Screen Mom ...
# 429                                        (HP 61 ink)
# 430                 (VIVO Dual LCD Monitor Desk mount)
# 431                    (Screen Mom Screen Cleaner kit)
#
#                                            consequents   support  confidence  \
# 0                   (10ft iPHone Charger Cable 2 Pack)  0.023064    0.096756
# 1                     (Dust-Off Compressed Gas 2 pack)  0.023064    0.456464
# 2                                          (HP 61 ink)  0.010132    0.200528
# 3                   (10ft iPHone Charger Cable 2 Pack)  0.010132    0.061839
# 4                      (Screen Mom Screen Cleaner kit)  0.015198    0.300792
# ..                                                 ...       ...         ...
# 427                 (VIVO Dual LCD Monitor Desk mount)  0.010932    0.340249
# 428                                        (HP 61 ink)  0.010932    0.308271
# 429  (VIVO Dual LCD Monitor Desk mount, Screen Mom ...  0.010932    0.066721
# 430         (HP 61 ink, Screen Mom Screen Cleaner kit)  0.010932    0.062787
# 431      (HP 61 ink, VIVO Dual LCD Monitor Desk mount)  0.010932    0.084362
#
#          lift
# 0    1.914955
# 1    1.914955
# 2    1.223888
# 3    1.223888
# 4    2.321232
# ..        ...
# 427  1.954217
# 428  1.881480
# 429  1.881480
# 430  1.954217
# 431  2.152382
#
# [432 rows x 5 columns]

# %% [markdown]
# ### Plot the support by lift to find a good threshold number

# %%
sns.scatterplot(data = rules, x = 'support', y = 'lift').set(Title= 'Support vs. Lift')
# Out:
# <ipython-input-11-64555317c61d>:1: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   sns.scatterplot(data = rules, x = 'support', y = 'lift').set(Title= 'Support vs. Lift')
# [Text(0.5, 1.0, 'Support vs. Lift')]

# %% [markdown]
# ### Generate the Association Rules of the frequent itemsets found by the Apriori Algorithm with another confidence threshold

# %%
rules = association_rules(frequent_itemsets,
                         metric = 'confidence',
                         min_threshold = 0.15)
print(rules.shape)
rules
# Out:
# (229, 9)
#                                            antecedents  \
# 0                   (10ft iPHone Charger Cable 2 Pack)
# 1                   (10ft iPHone Charger Cable 2 Pack)
# 2                   (10ft iPHone Charger Cable 2 Pack)
# 3                   (10ft iPHone Charger Cable 2 Pack)
# 4                     (3A USB Type C Cable 3 pack 6FT)
# ..                                                 ...
# 224  (Dust-Off Compressed Gas 2 pack, VIVO Dual LCD...
# 225  (USB 2.0 Printer cable, VIVO Dual LCD Monitor ...
# 226      (HP 61 ink, VIVO Dual LCD Monitor Desk mount)
# 227         (HP 61 ink, Screen Mom Screen Cleaner kit)
# 228  (VIVO Dual LCD Monitor Desk mount, Screen Mom ...
#
#                             consequents  antecedent support  \
# 0      (Dust-Off Compressed Gas 2 pack)            0.050527
# 1                           (HP 61 ink)            0.050527
# 2       (Screen Mom Screen Cleaner kit)            0.050527
# 3    (VIVO Dual LCD Monitor Desk mount)            0.050527
# 4      (Dust-Off Compressed Gas 2 pack)            0.042528
# ..                                  ...                 ...
# 224             (USB 2.0 Printer cable)            0.059725
# 225    (Dust-Off Compressed Gas 2 pack)            0.027596
# 226     (Screen Mom Screen Cleaner kit)            0.039195
# 227  (VIVO Dual LCD Monitor Desk mount)            0.032129
# 228                         (HP 61 ink)            0.035462
#
#      consequent support   support  confidence      lift  leverage  conviction
# 0              0.238368  0.023064    0.456464  1.914955  0.011020    1.401255
# 1              0.163845  0.010132    0.200528  1.223888  0.001853    1.045884
# 2              0.129583  0.015198    0.300792  2.321232  0.008651    1.244861
# 3              0.174110  0.014265    0.282322  1.621513  0.005468    1.150780
# 4              0.238368  0.017064    0.401254  1.683336  0.006927    1.272045
# ..                  ...       ...         ...       ...       ...         ...
# 224            0.170911  0.010132    0.169643  0.992583 -0.000076    0.998473
# 225            0.238368  0.010132    0.367150  1.540263  0.003554    1.203494
# 226            0.129583  0.010932    0.278912  2.152382  0.005853    1.207088
# 227            0.174110  0.010932    0.340249  1.954217  0.005338    1.251821
# 228            0.163845  0.010932    0.308271  1.881480  0.005122    1.208790
#
# [229 rows x 9 columns]

# %% [markdown]
# ### Further scrutinize the Association Rules by adding a threshold of 2.5 for Lift

# %%
rules = rules[rules['lift']>2.5]
rules
# Out:
#                                            antecedents  \
# 149               (SanDisk 128GB Ultra microSDXC card)
# 150                          (SanDisk Ultra 64GB card)
# 191  (Dust-Off Compressed Gas 2 pack, VIVO Dual LCD...
# 194              (FEIYOLD Blue light Blocking Glasses)
# 213  (Dust-Off Compressed Gas 2 pack, VIVO Dual LCD...
# 216                          (SanDisk Ultra 64GB card)
#
#                                            consequents  antecedent support  \
# 149                          (SanDisk Ultra 64GB card)            0.049460
# 150               (SanDisk 128GB Ultra microSDXC card)            0.098254
# 191              (FEIYOLD Blue light Blocking Glasses)            0.059725
# 194  (Dust-Off Compressed Gas 2 pack, VIVO Dual LCD...            0.065858
# 213                          (SanDisk Ultra 64GB card)            0.059725
# 216  (Dust-Off Compressed Gas 2 pack, VIVO Dual LCD...            0.098254
#
#      consequent support   support  confidence      lift  leverage  conviction
# 149            0.098254  0.015998    0.323450  3.291994  0.011138    1.332860
# 150            0.049460  0.015998    0.162822  3.291994  0.011138    1.135410
# 191            0.065858  0.010265    0.171875  2.609786  0.006332    1.128021
# 194            0.059725  0.010265    0.155870  2.609786  0.006332    1.113898
# 213            0.098254  0.017064    0.285714  2.907928  0.011196    1.262445
# 216            0.059725  0.017064    0.173677  2.907928  0.011196    1.137902

# %% [markdown]
# ### Plot the support vs lift and confidence of our association rules

# %%
fig, (ax1,ax2)  = plt.subplots(ncols = 2, sharey = False)
fig.tight_layout(w_pad = 3)
sns.scatterplot(data = rules, x = 'support', y = 'lift', ax = ax1).set(Title= 'Support vs. Lift')
sns.scatterplot(data = rules, x = 'support', y = 'confidence', ax = ax2).set(Title = 'Support vs. Confidence')
# Out:
# <ipython-input-14-269a331a09a2>:3: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   sns.scatterplot(data = rules, x = 'support', y = 'lift', ax = ax1).set(Title= 'Support vs. Lift')
# <ipython-input-14-269a331a09a2>:4: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   sns.scatterplot(data = rules, x = 'support', y = 'confidence', ax = ax2).set(Title = 'Support vs. Confidence')
# [Text(0.5, 1.0, 'Support vs. Confidence')]

# %% [markdown]
# ### Identify the top three rules from our association rules

# %%
rules.head(3)
# Out:
#                                            antecedents  \
# 149               (SanDisk 128GB Ultra microSDXC card)
# 150                          (SanDisk Ultra 64GB card)
# 191  (Dust-Off Compressed Gas 2 pack, VIVO Dual LCD...
#
#                                consequents  antecedent support  \
# 149              (SanDisk Ultra 64GB card)            0.049460
# 150   (SanDisk 128GB Ultra microSDXC card)            0.098254
# 191  (FEIYOLD Blue light Blocking Glasses)            0.059725
#
#      consequent support   support  confidence      lift  leverage  conviction
# 149            0.098254  0.015998    0.323450  3.291994  0.011138    1.332860
# 150            0.049460  0.015998    0.162822  3.291994  0.011138    1.135410
# 191            0.065858  0.010265    0.171875  2.609786  0.006332    1.128021

# %% [markdown]
# ### Support, Confidence, and Lift of our top three rules

# %%
rules[['antecedents','consequents','support','confidence','lift']].head(3)
# Out:
#                                            antecedents  \
# 149               (SanDisk 128GB Ultra microSDXC card)
# 150                          (SanDisk Ultra 64GB card)
# 191  (Dust-Off Compressed Gas 2 pack, VIVO Dual LCD...
#
#                                consequents   support  confidence      lift
# 149              (SanDisk Ultra 64GB card)  0.015998    0.323450  3.291994
# 150   (SanDisk 128GB Ultra microSDXC card)  0.015998    0.162822  3.291994
# 191  (FEIYOLD Blue light Blocking Glasses)  0.010265    0.171875  2.609786
